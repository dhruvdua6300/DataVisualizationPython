# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('gradedata.csv')

# %%
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df2 = df.take(np.random.permutation(len(df))[:500])

# %%
df2
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 598     Kaitlin  Mccarthy  female   17         1     14   95.4
# 1217     Jakeem     Lynch    male   14         4      5   78.8
# 384      Elijah      Bell    male   19         5     16   88.4
# 993     Harriet      Paul  female   14         3     14   89.5
# 1818      Caleb   Francis    male   17         3     11   76.8
# ...         ...       ...     ...  ...       ...    ...    ...
# 461       Emery  Shepherd    male   14         5     11   89.0
# 1190  Aristotle      Lang    male   15         3     13   77.3
# 505       Sonia     Kelly  female   17         4      7   83.6
# 1093      Zenia    Rhodes  female   16         5     11   92.0
# 633     Carissa    Fuller  female   18         3      7   76.8
#
#                                         address
# 598   158 North Linda Ave., Cambridge, MA 02138
# 1217        79 West Saxon St., Corona, NY 11368
# 384        5 Plymouth Ave., Lake Mary, FL 32746
# ...
