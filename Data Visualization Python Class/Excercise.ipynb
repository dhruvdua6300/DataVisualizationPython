# %% [markdown]
# 1.Write a Python script to create a data frame for the
# following table:
# Name Mobile_Sales TV_Sales
# Ahmed 2540 2200
# Omar 1370 1900
# Ali 1320 2150
# Ziad 2000 1850
# Salwa 2100 1770
# Lila 2150 2000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
salesMen = ['Ahmed', 'Omar', 'Ali', 'Ziad', 'Salwa', 'Lila']
Mobile_Sales = [2540, 1370, 1320, 2000, 2100, 2150]
TV_Sales = [2200, 1900, 2150, 1850, 1770, 2000]

# %%
df = pd.DataFrame()
df ['Name'] =salesMen
df ['Mobile_Sales'] = Mobile_Sales
df['TV_Sales']=TV_Sales
df.set_index("Name",drop=True,inplace=True)

# %%
df
# Out:
#        Mobile_Sales  TV_Sales
# Name
# Ahmed          2540      2200
# Omar           1370      1900
# Ali            1320      2150
# Ziad           2000      1850
# Salwa          2100      1770
# Lila           2150      2000

# %% [markdown]
# A. Create a bar plot of the sales volume.

# %%
df.plot.bar( figsize=(20, 10), rot=0).legend(bbox_to_anchor=(1.1, 1))
plt.xlabel('Salesmen') 
plt.ylabel('Sales')
plt.title('Sales Volume for two salesmen in \nJanuary and April 2017')
plt.show()

# %% [markdown]
# B. Create a pie chart of item sales.

# %%
df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001D91B386308>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D91AF49A08>],
#       dtype=object)

# %% [markdown]
# C. Create a box plot of item sales.

# %%
df.plot.box()

# %% [markdown]
# D. Create an area plot of item sales.

# %%
df.plot.area(figsize=(6, 4)).legend(bbox_to_anchor=(1.3,
1))

# %% [markdown]
# E. Create a stacked bar plot of item sales.

# %%
df.plot.bar(stacked=True, figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))
